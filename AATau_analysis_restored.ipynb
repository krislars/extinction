# %%
from matplotlib import pyplot as plt
import matplotlib
# %matplotlib inline
# %matplotlib notebook
# matplotlib.use('qt4agg')

# %%
import numpy as np

# %%
import scipy.interpolate as interp

# %%
run getAATau.py

# %%
# a,b,c,d,e,f,g,h=getAATau(9,1.156,4,1.050,0.9504,0.9133)
IRwavelength_2008,IRdata_2008,wavelength_2008,data_2008,IRwavelength_dec02,IRdata_dec02,wavelength_dec02,data_dec02=getAATau(9,1.156,4,1.050,0.9504,0.9133)

# %%
writeout=np.array([IRwavelength_2008,IRdata_2008])
np.savetxt("AATau_IR2008.txt",np.transpose(writeout),fmt="%.6e")
writeout=np.array([wavelength_2008,data_2008])
np.savetxt("AATau_opt2008.txt",np.transpose(writeout),fmt="%.6e")
writeout=np.array([IRwavelength_dec02,IRdata_dec02])
np.savetxt("AATau_IR2014.txt",np.transpose(writeout),fmt="%.6e")
writeout=np.array([wavelength_dec02,data_dec02])
np.savetxt("AATau_opt2014.txt",np.transpose(writeout),fmt="%.6e")

# %%
# plt.plot(a,b)
# plt.plot(c,d)
# plt.plot(e,f)
# plt.plot(g,h)
# plt.ylim(-0.05E-13,1.0E-13)

# %%
fig,[ax1,ax2]=plt.subplots(1,2,figsize=[14,6])

ax1.plot(IRwavelength_2008,IRdata_2008,'b')
ax1.plot(wavelength_2008,data_2008,'b',label='AA Tau in 2008')
ax1.plot(IRwavelength_dec02,IRdata_dec02,'r',label='AA Tau in 2014')
ax1.plot(wavelength_dec02,data_dec02,'r')
ax1.legend(loc='best')

ax1.set_ylim(-0.05E-13,1.0E-13)
ax1.set_xlabel('$\lambda$ ($\mu m$)')
ax1.set_ylabel("Flux (erg/s/cm$^2$/A)")

ax2.plot(1./IRwavelength_2008,IRdata_2008,'b')
ax2.plot(1./wavelength_2008,data_2008,'b',label='AA Tau 2008')
ax2.plot(1./IRwavelength_dec02,IRdata_dec02,'r',label='AA Tau 2014')
ax2.plot(1./wavelength_dec02,data_dec02,'r')
ax2.legend(loc='best')

ax2.set_ylim(-0.05E-13,1.0E-13)
ax2.set_xlabel('$\lambda^{-1}$ ($\mu m^{-1}$)')
ax2.set_ylabel("Flux (erg/s/cm$^2$/A)")



fig.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
run getMag_hires.py

# %%
getMag_hires('V',wavelength_2008,data_2008*10.0),getMag_hires('V',wavelength_dec02,data_dec02*10.0)
# Out:
# (12.639127100690544, 14.896261657666249)

# %%
f_dec02=interp.interp1d(wavelength_dec02,data_dec02)
IRf_dec02=interp.interp1d(IRwavelength_dec02,IRdata_dec02)

# %%
run getExt.py

# %%
fig,ax=plt.subplots(figsize=[6,4])
skip=100
ax.plot(1./wavelength_2008[skip:],-2.5*np.log10(np.abs(f_dec02(wavelength_2008[skip:])/data_2008[skip:])),'b-')
ax.plot(1./IRwavelength_2008[skip:],-2.5*np.log10(np.abs(IRf_dec02(IRwavelength_2008[skip:])/IRdata_2008[skip:])),'b-')

A=2.3
R=2.0
ax.plot(1./IRwavelength_2008,A*getFMext(IRwavelength_2008,R)/R,'red',label='')
ax.plot(1./wavelength_2008[900:],A*getFMext(wavelength_2008[900:],R)/R,'red',label='A(V)=2.3,R=2 FM99')
A=2.3
R=3.0
ax.plot(1./IRwavelength_2008,A*getFMext(IRwavelength_2008,R)/R,'orange',label='')
ax.plot(1./wavelength_2008[900:],A*getFMext(wavelength_2008[900:],R)/R,'orange',label='A(V)=2.3,R=3 FM99')
A=2.3
R=4.0
ax.plot(1./IRwavelength_2008,A*getFMext(IRwavelength_2008,R)/R,'green',label='')
ax.plot(1./wavelength_2008[900:],A*getFMext(wavelength_2008[900:],R)/R,'green',label='A(V)=2.3,R=4 FM99')

ax.set_ylabel('A($\lambda$)')
ax.set_xlabel('inverse wavelength (inverse microns)')
ax.set_ylim(-0.5,4)
ax.set_xlim(0,3.1)
ax.legend(loc='best')
# ax.set_title('AA Tau')
fig.show()
# Out:
# /Users/kristen/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
IRwavelength_2008,wavelength_2008,IRdata_2008,data_2008
# Out:
# (array([ 0.9106732 ,  0.91079736,  0.91092151, ...,  2.47030735,
#          2.47059107,  2.47087479], dtype=float32),
#  array([ 0.320097,  0.320201,  0.320305, ...,  0.870203,  0.87045 ,
#          0.870698]),
#  array([  6.41243108e-14,   6.04884727e-14,   6.45439174e-14, ...,
#           1.69818214e-14,   1.70019045e-14,   1.68158520e-14], dtype=float32),
#  array([  6.54829000e-15,   1.32147000e-14,   8.43663000e-15, ...,
#           4.60768000e-14,   4.58212000e-14,   5.00205000e-14]))

# %%
plt.plot(np.concatenate([wavelength_2008,IRwavelength_2008]),np.concatenate([data_2008,IRdata_2008]))

# %%
IRwavelength_2008,IRdata_2008,wavelength_2008,data_2008,IRwavelength_dec02,IRdata_dec02,wavelength_dec02,data_dec02=getAATau(9,1.156,4,1.050,0.9504,1.29)
getMag_hires('V',wavelength_2008,data_2008*10.0),getMag_hires('V',wavelength_dec02,data_dec02*10.0)
# Out:
# (12.639127100690544, 14.521321031172697)

# %%
wavelength2008=np.concatenate([wavelength_2008,IRwavelength_2008])
data2008=np.concatenate([data_2008,IRdata_2008])
wavelength2014=np.concatenate([wavelength_dec02,IRwavelength_dec02])
data2014=np.concatenate([data_dec02,IRdata_dec02])

# %%
getMag_hires('V',wavelength2008,data2008*10.0),getMag_hires('V',wavelength2014,data2014*10.0)
# Out:
# (12.639325476911417, 14.522123272618794)

# %%
run getMag_ext.py

# %%
plt.plot(wavelength2008,data2008)
plt.plot(IRwavelength_2008,1.5*IRdata_2008)
plt.plot(wavelength_2008,1.5*data_2008)

# %% [markdown]
# FIGURE OUT WHY THIS DOESN'T WORK:

# %%
getMag_ext('Ks',wavelength2008,A*getFMext(wavelength2008,R)/R)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-555162b3f434> in <module>()
# ----> 1 getMag_ext('Ks',wavelength2008,A*getFMext(wavelength2008,R)/R)
#
# /Users/kristen/Dropbox/Python/getExt.py in getFMext(x, R)
#      63     f=interp1d(f99_anchor,af99_anchor, kind='cubic')
#      64
# ---> 65     return f(1.0/x)
#      66
#      67
#
# /Users/kristen/anaconda/lib/python3.5/site-packages/scipy/interpolate/polyint.py in __call__(self, x)
#      77         """
#      78         x, x_shape = self._prepare_x(x)
# ---> 79         y = self._evaluate(x)
#      80         return self._finish_y(y, x_shape)
#      81
#
# /Users/kristen/anaconda/lib/python3.5/site-packages/scipy/interpolate/interpolate.py in _evaluate(self, x_new)
#     586         y_new = self._call(self, x_new)
#     587         if not self._extrapolate:
# ...

# %%
V2008=getMag_hires('V',wavelength_2008,data_2008*10.0)
B2008=getMag_hires('B',wavelength_2008,data_2008*10.0)
R2008=getMag_hires('R',wavelength_2008,data_2008*10.0)
J2008=getMag_hires('J',IRwavelength_2008,IRdata_2008*10.0)
H2008=getMag_hires('H',IRwavelength_2008,IRdata_2008*10.0)
K2008=getMag_hires('Ks',IRwavelength_2008,IRdata_2008*10.0)

# %%
B2008,V2008,R2008,J2008,H2008,K2008
# Out:
# (14.271666404728142,
#  12.639127100690544,
#  12.70310136633147,
#  9.5132128401150453,
#  8.6462445595353614,
#  8.1826227036918624)

# %%
V2008=getMag_hires('V',wavelength2008,data2008*10.0)
B2008=getMag_hires('B',wavelength2008,data2008*10.0)
R2008=getMag_hires('R',wavelength2008,data2008*10.0)
J2008=getMag_hires('J',wavelength2008,data2008*10.0)
H2008=getMag_hires('H',wavelength2008,data2008*10.0)
K2008=getMag_hires('Ks',wavelength2008,data2008*10.0)

B2008,V2008,R2008,J2008,H2008,K2008
# Out:
# (14.272175905062539,
#  12.639325476911417,
#  12.699218221338388,
#  9.5132128398696185,
#  8.646244560041497,
#  8.1826227046006466)

# %%
fig,[ax1,ax2]=plt.subplots(1,2,figsize=[15,6])


for allscale in [.6,.7,.8,.9,1.0,1.1,1.2,1.3]:
    IRwavelength_2008,IRdata_2008,wavelength_2008,data_2008,IRwavelength_dec02,IRdata_dec02,wavelength_dec02,data_dec02=getAATau(9,1.156,4,1.050,0.9504,allscale)
    f_dec02=interp.interp1d(wavelength_dec02,data_dec02)
    IRf_dec02=interp.interp1d(IRwavelength_dec02,IRdata_dec02)
    ax1.plot(1./wavelength_2008[1000:],-2.5*np.log10(np.abs(f_dec02(wavelength_2008[1000:])/data_2008[1000:])),'grey')
    ax1.plot(1./IRwavelength_2008[1000:],-2.5*np.log10(np.abs(IRf_dec02(IRwavelength_2008[1000:])/IRdata_2008[1000:])),'grey')
    ax2.scatter(K2008,V2008,c='black')
    ax2.scatter(getMag_hires('Ks',IRwavelength_dec02,IRdata_dec02*10.0),getMag_hires('V',wavelength_dec02,data_dec02*10.0),c='grey')

color=iter(plt.cm.rainbow(np.linspace(0,1,9)))

allscale=0.9133

for A in [2.77,2.22,1.67]:
    for R in [2.0,3.0,4.0]:
        c=next(color)
        ax1.plot(1./IRwavelength_2008,A*getFMext(IRwavelength_2008,R)/R,c=c,label='')
        ax1.plot(1./wavelength_2008[1000:],A*getFMext(wavelength_2008[1000:],R)/R,c=c,label='A(V)='+str(A)+', R='+str(R)+' FM99')
        AK=getMag_ext('Ks',IRwavelength_2008,A*getFMext(IRwavelength_2008,R)/R)
        AV=getMag_ext('V',wavelength_2008[1000:],A*getFMext(wavelength_2008[1000:],R)/R)
        ax2.arrow(K2008,V2008,AK,AV,color=c,head_width=0.02, head_length=0.1)
        ax2.plot(K2008+AK,V2008+AV,'o',c=c,label='AK='+str(round(AK,2))+' AV='+str(round(AV,2)))
        
# why [1000:] in the above??
        
ax1.set_ylabel('$A(\lambda)$')
ax1.set_xlabel('$\lambda^{-1} (\mu m^{-1})$')
ax1.set_ylim(-0.5,4)
ax1.set_xlim(0,3.1)
ax1.legend(loc='best')

ax2.set_xlabel('$Ks$')
ax2.set_ylabel('$V$')
ax2.legend(loc='lower right')

fig.show()
# Out:
# /Users/kristen/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
fig,[ax1,ax2]=plt.subplots(1,2,figsize=[14,6])


for allscale in [.6,.7,.8,.9,1.0,1.1,1.2,1.3]:
    IRwavelength_2008,IRdata_2008,wavelength_2008,data_2008,IRwavelength_dec02,IRdata_dec02,wavelength_dec02,data_dec02=getAATau(9,1.156,4,1.050,0.9504,allscale)
    f_dec02=interp.interp1d(wavelength_dec02,data_dec02)
    IRf_dec02=interp.interp1d(IRwavelength_dec02,IRdata_dec02)
    ax1.plot(wavelength_2008[1000:],-2.5*np.log10(np.abs(f_dec02(wavelength_2008[1000:])/data_2008[1000:])),'grey')
    ax1.plot(IRwavelength_2008[1000:],-2.5*np.log10(np.abs(IRf_dec02(IRwavelength_2008[1000:])/IRdata_2008[1000:])),'grey')
    ax2.plot(1./wavelength_2008[1000:],-2.5*np.log10(np.abs(f_dec02(wavelength_2008[1000:])/data_2008[1000:])),'grey')
    ax2.plot(1./IRwavelength_2008[1000:],-2.5*np.log10(np.abs(IRf_dec02(IRwavelength_2008[1000:])/IRdata_2008[1000:])),'grey')
    
color=iter(plt.cm.plasma(np.linspace(0,1,9)))

allscale=0.9133

for A in [2.77,2.22,1.67]:
    for R in [2.0,3.0,4.0]:
        c=next(color)
        ax1.plot(IRwavelength_2008,A*getFMext(IRwavelength_2008,R)/R,c=c,label='')
        ax1.plot(wavelength_2008[1000:],A*getFMext(wavelength_2008[1000:],R)/R,c=c,label='A(V)='+str(A)+', R='+str(R)+' FM99')
        ax2.plot(1./IRwavelength_2008,A*getFMext(IRwavelength_2008,R)/R,c=c,label='')
        ax2.plot(1./wavelength_2008[1000:],A*getFMext(wavelength_2008[1000:],R)/R,c=c)
        
ax2.set_ylabel('$A(\lambda)$')
ax2.set_xlabel('$\lambda^{-1} (\mu m^{-1})$')
ax2.set_ylim(-0.5,4)
ax2.set_xlim(0,2.5)

        
# why [1000:] in the above??
        
ax1.set_ylabel('$A(\lambda)$')
ax1.set_xlabel('$\lambda\ (\mu m)$')
ax1.set_ylim(-0.5,4)
# ax1.set_xlim(0,3.1)
ax1.legend(loc='best')

        

fig.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
fig,[ax1,ax2,ax3]=plt.subplots(1,3,figsize=[15,6])

color=iter(plt.cm.plasma(np.linspace(0,1,9)))

for allscale in [.6,.7,.8,.9,1.0,1.1,1.2,1.3]:
    IRwavelength_2008,IRdata_2008,wavelength_2008,data_2008,IRwavelength_dec02,IRdata_dec02,wavelength_dec02,data_dec02=getAATau(9,1.156,4,1.050,0.9504,allscale)
    wavelength2014=np.concatenate([wavelength_dec02,IRwavelength_dec02])
    data2014=np.concatenate([data_dec02,IRdata_dec02])
#    f_dec02=interp.interp1d(wavelength_dec02,data_dec02)
#    IRf_dec02=interp.interp1d(IRwavelength_dec02,IRdata_dec02)
#    K2014=getMag_hires('Ks',IRwavelength_dec02,IRdata_dec02*10.0)
#    H2014=getMag_hires('H',IRwavelength_dec02,IRdata_dec02*10.0)
#    J2014=getMag_hires('J',IRwavelength_dec02,IRdata_dec02*10.0)
#    V2014=getMag_hires('V',wavelength_dec02,data_dec02*10.0)
#    B2014=getMag_hires('B',wavelength_dec02,data_dec02*10.0)
#    R2014=getMag_hires('R',wavelength_dec02,data_dec02*10.0)
    K2014=getMag_hires('Ks',wavelength2014,data2014*10.0)
    H2014=getMag_hires('H',wavelength2014,data2014*10.0)
    J2014=getMag_hires('J',wavelength2014,data2014*10.0)
    V2014=getMag_hires('V',wavelength2014,data2014*10.0)
    B2014=getMag_hires('B',wavelength2014,data2014*10.0)
    R2014=getMag_hires('R',wavelength2014,data2014*10.0)
    ax1.plot(V2014-R2014,V2014,'o',c='grey')
    ax1.arrow(V2008-R2008,V2008,V2014-R2014-(V2008-R2008),V2014-V2008,color='grey',head_width=0.05, head_length=0.1)
    ax2.plot(V2014-R2014,R2014-K2014,'o',c='grey')
    ax2.arrow(V2008-R2008,R2008-K2008,V2014-R2014-(V2008-R2008),R2014-K2014-(R2008-K2008),color='grey',head_width=0.05, head_length=0.1)
    ax3.plot(H2014-K2014,J2014-H2014,'o',c='grey')
    ax3.arrow(H2008-K2008,J2008-H2008,H2014-K2014-(H2008-K2008),J2014-H2014-(J2008-H2008),color='grey',head_width=0.02, head_length=0.02)
    
for A in [2.77,2.22,1.67]:
    for R in [2.0,3.0,4.0]:
        c=next(color)
        AJ=getMag_ext('J',IRwavelength_2008,A*getFMext(IRwavelength_2008,R)/R)
        AH=getMag_ext('H',IRwavelength_2008,A*getFMext(IRwavelength_2008,R)/R)
        AK=getMag_ext('Ks',IRwavelength_2008,A*getFMext(IRwavelength_2008,R)/R)

        AV=getMag_ext('V',wavelength_2008[1000:],A*getFMext(wavelength_2008[1000:],R)/R)
        AB=getMag_ext('B',wavelength_2008[1000:],A*getFMext(wavelength_2008[1000:],R)/R)
        AR=getMag_ext('R',wavelength_2008[1000:],A*getFMext(wavelength_2008[1000:],R)/R)

        ax1.plot(V2008-R2008,V2008,'o',c='black')
        ax1.plot(V2008-R2008+(AV-AR),V2008+AV,'o',c=c,label='A(V)='+str(A)+', R='+str(R))
        ax1.arrow(V2008-R2008,V2008,(AV-AR),AV,color=c,head_width=0.05, head_length=0.1)

        ax2.plot(V2008-R2008,R2008-K2008,'o',c='black')
        ax2.plot(V2008-R2008+(AV-AR),R2008-K2008+(AR-AK),'o',c=c)
        ax2.arrow(V2008-R2008,R2008-K2008,AV-AR,AR-AK,color=c,head_width=0.05, head_length=0.1)

        ax3.plot(H2008-K2008,J2008-H2008,'o',c='black')
        ax3.plot(H2008-K2008+(AH-AK),J2008-H2008+(AJ-AH),'o',c=c,label='AK='+str(round(AK,2))+' AV='+str(round(AV,2)))
        ax3.arrow(H2008-K2008,J2008-H2008,AH-AK,AJ-AH,color=c,head_width=0.02, head_length=0.02)

ax1.set_xlabel('$V-R$')
ax1.set_ylabel('$V$')
ax1.legend(loc='upper right')
ax1.set_xlim(-.1,.9)
ax1.set_ylim(15.5,12.5)

ax2.set_xlabel('$V-R$')
ax2.set_ylabel('$R-K$')
ax2.legend(loc='lower right')
ax1.set_xlim(-.1,.9)

ax3.set_xlabel('$H-K$')
ax3.set_ylabel('$J-H$')
ax3.legend(loc='lower right')

fig.show()
# Out:
# <img src="data:image/png;base64,...">
# /Users/kristen/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
center=2.159         
halfwidth=0.262/2.0  
dwav=np.zeros(IRwavelength_2008.size)
dwav[0:-1]=IRwavelength_2008[1:]-IRwavelength_2008[0:-1]
filterband=np.zeros(IRwavelength_2008.size)
filterband[(IRwavelength_2008<center+halfwidth) & (IRwavelength_2008>center-halfwidth)]=1.0
A=2.22
R=3.0
flux=A*getFMext(IRwavelength_2008,R)/R
# 2.5*np.log10((np.sum(10.0**(-flux*dwav*filterband)))
-2.5*np.log10((np.sum(10.0**(-flux*0.4)*dwav*filterband))/np.sum(dwav*filterband))
# Out:
# 0.26047160243136414

# %%
# plt.plot(IRwavelength_2008,10.0**(-flux*0.4*dwav)*filterband)
plt.plot(IRwavelength_2008,10.0**(-flux*0.4)*filterband)

# %%
plt.plot(IRwavelength_2008,dwav)
plt.ylim(0,.001)
# Out:
# (0, 0.001)
